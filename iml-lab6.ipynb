# %%
# Write a Pandas program to implement following operation
# to convert a NumPy array to a Pandas series

import numpy as np
import pandas as pd
array = np.array([1, 2,3, 4, 5, 6, 7, 8])
print("Numpy array:- ",array)
series = pd.Series(array)
print("Pandas Series : \n",series)

# %%
#Write a perogram to implement  following opration
#to convert the first column of a DataFrame as a Series

import pandas as pd  
xy = pd.DataFrame() 
print(xy)
xy = pd.DataFrame({'A':[21,22,23],'B':[64,65,66],}) 
print("Dataframe:")
print(xy)

# %%
#Write a Pandas program to implement following operation
#to create the mean and standard deviation of the data of a given Series
import numpy as np
import pandas as pd
s = pd.Series(data = [1, 2, 3,4, 5, 6, 7, 8])
print(s)

# %%
#Write a Pandas program to implement following operation
#to sort a given Series
import pandas as pd
import numpy as np
sr = pd.Series([1,2,4,5,3])
print(sr)
print(sr.sort_values(ascending=True))
